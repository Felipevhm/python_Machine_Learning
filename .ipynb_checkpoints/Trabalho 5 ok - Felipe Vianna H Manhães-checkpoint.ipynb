# %% [markdown]
# Universidade Federal de Santa Catarina<br>
# Departamento de Engenharia Elétrica e Eletrônica<br>
# EEL7514/EEL7513/EEL410250 - Aprendizado de Máquina
# $\newcommand{\bX}{\mathbf{X}}$
# $\newcommand{\bw}{\mathbf{w}}$
# $\newcommand{\by}{\mathbf{y}}$
# $\newcommand{\bx}{\mathbf{x}}$
# $\newcommand{\RR}{\mathbb{R}}$
# $\newcommand{\calS}{\mathcal{S}}$
#
#
# # Exercício 5: SVM
#
# Neste exercício você irá construir classificadores usando máquinas de vetores de suporte (SVM), tando em sua versão linear quanto na versão baseada em kernels. Também serão abordadas técnicas de validação cruzada para avaliação de desempenho e busca de hiperparâmetros.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import scipy.io as sio
import wget
#from scipy.io import loadmat .

from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
import scipy.io as sio

def plot_data(X, y, colors=['bo','rx','gs','md','c^','yP']):
    ''' Plot 1-D or 2-D classification dataset '''
    assert len(X.shape) == 2 and len(y.shape) == 1
    classes = np.unique(y)
    assert len(classes) <= len(colors)
    dim = X.shape[1]
    assert 0 < dim <= 2
    if dim == 1:
        for i in range(len(classes)):
            plt.plot(X[y==classes[i],0],np.zeros(np.sum(y==classes[i])),colors[i])
        plt.gca().axes.get_yaxis().set_ticks([])
    else:
        for i in range(len(classes)):
            plt.plot(X[y==classes[i],0],X[y==classes[i],1],colors[i])
    return

def plot_svm(model, X, heatmap=False, circles=None, N=100, gap=1e-9):
    ''' Plot decision regions for a 1-D or 2-D binary SVM classifier '''
    assert len(X.shape) == 2
    dim = X.shape[1]
    assert 0 < dim <= 2
    x1_min, x1_max = X[:,0].min()-gap, X[:,0].max()+gap
    if dim == 1:
        x2_min, x2_max = -1, 1
        N2 = 2
    else:
        x2_min, x2_max = X[:,1].min()-gap, X[:,1].max()+gap
        N2 = N
    xx1, xx2 = np.meshgrid(np.linspace(x1_min,x1_max,N), np.linspace(x2_min,x2_max,N2))
    if dim == 1:
        X = np.c_[xx1.reshape(-1)]
    else:
        X = np.c_[xx1.reshape(-1), xx2.reshape(-1)]
    z = model.decision_function(X)
    assert len(z.shape) == 1
    z = z.reshape(xx1.shape)
    plt.contourf(xx1,xx2,np.sign(z),cmap=plt.cm.bwr,vmin=-3,vmax=3)
    plt.contour(xx1,xx2,z,cmap=plt.cm.gray,vmin=np.inf,vmax=np.inf,levels=[0])
    if heatmap:
        a = np.max(np.abs(z))*2
        plt.contourf(xx1,xx2,z,100,cmap=plt.cm.bwr,vmin=-a,vmax=a)
        if circles == None:
            circles = False
    else:
        plt.contourf(xx1,xx2,z,cmap=plt.cm.bwr,vmin=-3,vmax=3,levels=[-1,0,1])
        if circles == None:
            circles = True
    if circles:
        S = model.support_vectors_
        if dim == 1:
            S = np.c_[S, np.zeros(S.shape[0])]
        plt.plot(*S.T,'go',mfc='none',ms=12)
    return

# %% [markdown]
# # 1. Conjunto de dados #1
#
# O primeiro conjunto de dados pode ser carregado pelo comando abaixo. Para simplificar, não usaremos conjunto de teste.

# %%
if not os.path.exists('svm1.mat'):
    wget.download('https://github.com/danilo-silva-ufsc/ml/raw/master/data/svm1.mat')
data = sio.loadmat('svm1.mat')
X, y = data['X'], data['y'].reshape(-1)
plot_data(X, y)

# %%
model = SVC(C=1, kernel='linear')
model.fit(X, y)
print('Train accuracy: {:.1%}'.format(model.score(X, y)))
plot_data(X, y)
plot_svm(model,X)
# Out:
# Train accuracy: 98.0%

# %% [markdown]
# ## SVM linear
#
# Os círculos no gráfico acima marcam os **vetores de suporte**. Note que, no classificador SVM, o classificador é definido exclusivamente a partir dos vetores de suporte, i.e., as demais amostras de treinamento que satisfazem a margem não tem impacto no classificador.
#
# 1. Determine os vetores de suporte, os índices dos vetores de suporte, e o vetor de coeficientes da solução dual ($\alpha_i y_s^{(i)}$).
# 1. A partir deles, determine o vetor de pesos (da solução primal) $\bw$, bem como o termo de *bias* $b$. Confirme que os valores são os mesmos fornecidos pelo modelo (o termo $b$ até a segunda casa decimal).
#
# #### Dicas
# - Reveja as equações nos slides da disciplina.
# - Leia a documentação do SVC do sklearn em:
#  - https://scikit-learn.org/stable/modules/svm.html#svc
#  - https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
#--------Questão 1 ------------------------------------------------------------------------------

#---------Q1.1---------------------

  # vetores de suporte 
       #indices
spvec=model.support_vectors_
spindex=model.support_
dualcoef=model.dual_coef_
print("---- Questão 1.1 ----\n\na)Vetores de Suporte: \n",
      spvec,
      "\n\nb) Indices dos Vetores de Suporte: \n",
      spindex,
     "\n\nc) Coeficientes da solução dual (alpha_i*(y_s)^i): \n",
     dualcoef)
#---------Q1.2---------------------
aa=dualcoef@X[spindex]
# Out:
# ---- Questão 1.1 ----
#
# a)Vetores de Suporte:
#  [[1.5841   3.3575  ]
#  [2.0103   3.2039  ]
#  [2.3099   2.9584  ]
#  [2.8283   2.6309  ]
#  [1.3191   3.5109  ]
#  [2.5403   2.8867  ]
#  [3.5772   2.856   ]
#  [3.1048   3.0709  ]
#  [1.9182   4.0534  ]
#  [2.6555   3.5008  ]
#  [3.0357   3.3165  ]
#  [0.086405 4.1045  ]]
#
# b) Indices dos Vetores de Suporte:
#  [20 21 24 25 42 47  4 11 12 14 19 50]
#
# c) Coeficientes da solução dual (alpha_i*(y_s)^i):
#  [[-1.         -1.         -1.         -1.         -0.49924348 -1.
#    1.          1.          0.5695935   1.          0.92964998  1.        ]]

# %% [markdown]
# ### Variando $C$
#
# 3. Varie o valor de $C$ até obter 100% de acurácia.
# 1. Analise os resultados observados:
#  1. O que acontece com a fronteira de decisão? Por quê?
#  1. Que interpretação pode ser dada para o parâmetro $C$?
#  1. O ajuste obtido parece ser adequado? Explique.

# %%
#---------Q1.3---------------------
print("Q1.3) O valor de C que resulta em 100% de acurácia é de C=~ 24.828;")
#---------Q1.4A---------------------
print("Q1.4-A) A fronteira de decisão torna-se menor pois a penalização feita por conta da suavização da margem torna-se muito grande;")
print("Q1.4-B) O parâmetro 'C' tem a função de restrição dos parâmetros a serem considerados como vetores de suporte para o SVM ;")
print("Q1.4-C) O ajuste obtido está excessivamente adequado ao treino, no entanto, para uma distribuição distinta de amostras (teste), a margem reduzida resultará em menor acurácia;")
# Out:
# Q1.3) O valor de C que resulta em 100% de acurácia é de C=~ 24.828;
# Q1.4-A) A fronteira de decisão torna-se menor pois a penalização feita por conta da suavização da margem torna-se muito grande;
# Q1.4-B) O parâmetro 'C' tem a função de restrição dos parâmetros a serem considerados como vetores de suporte para o SVM ;
# Q1.4-C) O ajuste obtido está excessivamente adequado ao treino, no entanto, para uma distribuição distinta de amostras (teste), a margem reduzida resultará em menor acurácia;

# %% [markdown]
# ### Escala dos atributos
#
# 5. Para um modelo com $C=1$, reescale os atributos conforme a célula abaixo e verifique o impacto no modelo treinado. Como você explica as diferenças?
# 1. A partir dos resultados observados, que recomendação você daria para o treinamento de um classificador SVM?
#
# Ao final desta parte, **retorne os dados para a escala original**.

# %%
# Try each of them
#d = [0.1,10]
#d = [1,1]
#d = [10,0.1]
#X = data['X'] @ np.diag(d)

print("Q1.5) Quando as colunas dos parâmetros de X possuem amplitudes muito díspares, a regressão acaba por ocorrer incorretamente, pendendo para uma maior inflência dos atributos de maior amplitude;") 
print("Q1.6) Mostra-se prudente a realização de uma normalização dos atribuos antes do treinamento do modelo da SVM")
# Out:
# Q1.5) Quando as colunas dos parâmetros de X possuem amplitudes muito díspares, a regressão acaba por ocorrer incorretamente, pendendo para uma maior inflência dos atributos de maior amplitude;
# Q1.6) Mostra-se prudente a realização de uma normalização dos atribuos antes do treinamento do modelo da SVM

# %% [markdown]
# ## SVM com kernel RBF (gaussiano)
#
# Nesta parte você utilizará um kernel RBF para obter uma fronteira de decisão não-linear.
#
# Em geral, um kernel pode ser interpretado como uma função que mede a **similaridade** entre um par de amostras ($x^{(i)}$, $x^{(j)}$). No caso do kernel RBF, a similaridade é definida como uma função da distância euclidiana entre as amostras, mais precisamente:
#
# $$ K_{\text{RBF}} \left( x^{(i)}, x^{(j)} \right) = \exp \left( - \gamma \| x^{(i)} - x^{(j)}\|^2 \right) $$
#
# O parâmetro $\gamma$ (um **hiperparâmetro** do modelo) determina quão rápido a similaridade decai com a distância.
#
# Em contraste, o kernel linear não possui hiperparâmetros, sendo definido simplesmente como o produto interno entre amostras:
#
# $$ K_{\text{linear}} \left( x^{(i)}, x^{(j)} \right) = {x^{(i)}}^T x^{(j)} $$
#
# O uso do kernel linear resulta no classificador linear visto anteriormente.
#
# Em qualquer caso, a função de decisão (score de confiança) é dada por
# $$
# z = \bw^T \bx + b =b + \sum_{i \in \calS} \alpha_i y_s^{(i)} K(\bx^{(i)},\bx)
# $$
# onde $\calS$ denota o conjunto de índices dos vetores de suporte. Portanto, a predição é realizada calculando o kernel somente com relação aos vetores de suporte, i.e., apenas a similaridade com relação aos vetores de suporte é relevante.

# %% [markdown]
# ### Usando o kernel da biblioteca
#
# 7. Refaça a classificação utilizando o kernel `rbf` fornecido na própria função `SVC`, definindo e variando o parâmetro `gamma`.
# 1. O que você observa? Qual o efeito do parâmetro $\gamma$? Note que esse efeito pode ser melhor visualizado utilizando um valor muito alto para `C` (por exemplo, `C = 1e6`), o que corresponde a um problema praticamente sem regularização.
#
# Caso deseje, você pode utilizar a opção `heatmap` (possivelmente com `circles=True`) na função `plot_svm` para ajudar na visualização. Nesse caso as regiões mais vermelhas representam um valor de $z$ (discriminante ou função de decisão) mais positivo, enquanto as regiões mais azuis representam um valor de $z$ mais negativo (mas a margem deixa de ser mostrada).

# %%
#---------Q1.7---------------------

model = SVC(C=1e6, kernel='rbf',gamma=0.0001)
model.fit(X, y)
print('Train accuracy: {:.1%}'.format(model.score(X, y)))
plot_data(X, y)
plot_svm(model,X,)

#---------Q1.8---------------------
plot_svm(model, X, heatmap=True, circles=True)

print("Q1.8) Quanto maiores forem os valores de 'gamma', tanto mais as regiões de classificação se aproximarão em pequenas regiões em torno dos atributos, enquanto que valores menores farão com que as regiões de classificação possuam caráter mais linear, até chegar próximas de uma reta (gamma==0.0001)")
# Out:
# Train accuracy: 100.0%
# Q1.8) Quanto maiores forem os valores de 'gamma', tanto mais as regiões de classificação se aproximarão em pequenas regiões em torno dos atributos, enquanto que valores menores farão com que as regiões de classificação possuam caráter mais linear, até chegar próximas de uma reta (gamma==0.0001)

# %% [markdown]
# ### Implementando seu próprio kernel
#
# 9. Em seguida, implemente o seu próprio kernel RBF usando a função `my_kernel` definida abaixo. Como exemplo, está implementado um kernel linear.
#
# O kernel customizado pode ser usado na função SVC através do comando:
#
# ```python
# model = SVC(C=1, kernel=my_kernel)
# ```
#
# Nesse caso, o parâmetro `gamma` deve ser definido como variável global (externa à função), para que você possa variá-lo, uma vez que a biblioteca sklearn não permite passar argumentos adicionais para a função de kernel customizado (em particular, o parâmetro `gamma` do `SVC` é ignorado para qualquer kernel customizado).
#
# Alternativamente, você pode definir a função de kernel usando uma função anônima:
#
# ```python
# model = SVC(C=1, kernel=lambda X1, X2: my_kernel(X1,X2,gamma))
# ```
#
# e definir `gamma` como um argumento adicional de `my_kernel`.

# %%
'''
gamma=1
def my_kernel(X1, X2):
   
 #
    Computes custom kernel.
    
    Parameters
    ----------
    X1 : array of shape (m1, n_features)
    X2 : array of shape (m2, n_features)
    
    Returns
    -------
    kernel_matrix : array of shape (m1, m2)
    
   # 
    
    
    kernel_matrix =np.exp(-gamma*np.linalg.norm(X1-X2)**2)
    
    return kernel_matrix
    
'''
# Out:
# '\ngamma=1\ndef my_kernel(X1, X2):\n   \n #\n    Computes custom kernel.\n    \n    Parameters\n    ----------\n    X1 : array of shape (m1, n_features)\n    X2 : array of shape (m2, n_features)\n    \n    Returns\n    -------\n    kernel_matrix : array of shape (m1, m2)\n    \n   # \n    \n    \n    kernel_matrix =np.exp(-gamma*np.linalg.norm(X1-X2)**2)\n    \n    return kernel_matrix\n    \n'

# %% [markdown]
# Certifique-se que sua implementação está correta rodando o código abaixo.

# %%
'''
from sklearn.metrics.pairwise import rbf_kernel
X1 = np.random.randn(2,4) #(2,4)
X2 = np.random.randn(3,4)
gamma = 0.0001 #1/8
# kernel_matrix =np.exp(-gamma*np.linalg.norm(X1-X2)^2)
sim = my_kernel(X1, X2)
sim2 = rbf_kernel(X1, X2, gamma=gamma)
if abs(sim -sim2).sum() < 1e-10: print('OK')
abs(sim - sim2).sum()
'''
# Out:
# "\nfrom sklearn.metrics.pairwise import rbf_kernel\nX1 = np.random.randn(2,4) #(2,4)\nX2 = np.random.randn(3,4)\ngamma = 0.0001 #1/8\n# kernel_matrix =np.exp(-gamma*np.linalg.norm(X1-X2)^2)\nsim = my_kernel(X1, X2)\nsim2 = rbf_kernel(X1, X2, gamma=gamma)\nif abs(sim -sim2).sum() < 1e-10: print('OK')\nabs(sim - sim2).sum()\n"

# %% [markdown]
# 10. Em seguida, realize novamente a classificação para obter o mesmo resultado anterior.
#
# Após garantir que você conseguiu implementar corretamente um kernel RBF, **você pode voltar a usar o kernel da própria função SVC** (o qual tem provavelmente uma implementação mais eficiente).

# %% [markdown]
# # 2. Conjuntos de dados #2
#
# O próximo conjunto de dados pode ser carregado pelo comando abaixo. (Suponha novamente que todo esse conjunto esteja disponível para desenvolvimento.)

# %%
if not os.path.exists('svm2.mat'):
    wget.download('https://github.com/danilo-silva-ufsc/ml/raw/master/data/svm2.mat')
data = sio.loadmat('svm2.mat')
X, y = data['X'], data['y'].reshape(-1)
plot_data(X, y)

# %% [markdown]
# ## Variando hiperparâmetros
#
# 1. Utilize novamente um kernel RBF. Varie os hiperparâmetros $C$ e $\gamma$ e observe seus efeitos. Tente encontrar valores que forneçam uma explicação aparentemente mais "natural" possível para os dados.
# 1. Explique o seu raciocínio.

# %%
#----Q.2.1-----
model = SVC(C=5, kernel='rbf',gamma=25)
model.fit(X, y)
print('Train accuracy: {:.1%}'.format(model.score(X, y)))
plot_data(X, y)
plot_svm(model,X,)

#----Q.2.2------
print("\n\n--Questão 2.2------------")
print("\nOs valores de 'C' fazem com que a regiões de classificação seja mais ou menos centrada nas amostras obtidas e",
      " valores maiores dão maior ''liberdade'' de classificação par ao modelo, enquanto que os valores de 'gamma' ",
      "operam como que o ''ajuste fino'' do contorno das amostras. Com um 'gamma' muito alto pode haver overfitting.",
      " Foram mantidos os valores de C==5 e gamma==25 pois assim 98.6% das amostras foram corretamente classificadas ",
      "sem necessariamente comprometer uma maior tolerância da região a um conjunto distindo de atributos.")
# Out:
# Train accuracy: 98.6%
#
#
# --Questão 2.2------------
#
# Os valores de 'C' fazem com que a regiões de classificação seja mais ou menos centrada nas amostras obtidas e  valores maiores dão maior ''liberdade'' de classificação par ao modelo, enquanto que os valores de 'gamma'  operam como que o ''ajuste fino'' do contorno das amostras. Com um 'gamma' muito alto pode haver overfitting.  Foram mantidos os valores de C==5 e gamma==25 pois assim 98.6% das amostras foram corretamente classificadas  sem necessariamente comprometer uma maior tolerância da região a um conjunto distindo de atributos.

# %% [markdown]
# ## Experimentando outros kernels
#
# 3. Tente conseguir o mesmo resultado usando um kernel polinomial (semelhante a uma adição de atributos polinomiais). Para isto, utilize `kernel='poly'`, defina os parâmetros `degree=d`, `gamma='auto'`, `coef0=1` e varie $C$ e $d$. (Se desejar, varie `gamma`e `coef0` também, mas evite aumentar muito ou esteja preparado para eventualmente ter que reiniciar o interpretador.)
# 1. Que grau $d$ foi necessário? Como você compara as duas soluções, levando em conta também o ponto de vista prático?
# 1. (OPCIONAL) Experimente também `kernel=sigmoid`.

# %%
#----Questão 2.3------

model = SVC(C=1, kernel='poly',gamma='auto',degree=30,coef0=1)
model.fit(X, y)
print('Train accuracy: {:.1%}'.format(model.score(X, y)))
plot_data(X, y)
plot_svm(model,X,)

#----Questão 2.4------
print("\nQ2.4) Foi necessário usar d==30 para uma acurácia de 96.9%, um polinômio muito alto para um algoritmo",
      " que necessita otimizar a capacidade",
     "computacional do sistema. Assim, o modelo treinado por kernel se mostra mais viável por possuir um ajuste mais",
     "rápido do modelo, sem perder em flexibilidade de classificação, a um custo computacional menor.")
# Out:
# Train accuracy: 96.9%
#
# Q2.4) Foi necessário usar d==30 para uma acurácia de 96.9%, um polinômio muito alto para um algoritmo  que necessita otimizar a capacidade computacional do sistema. Assim, o modelo treinado por kernel se mostra mais viável por possuir um ajuste mais rápido do modelo, sem perder em flexibilidade de classificação, a um custo computacional menor.

# %%
# --------------- Questão 2.5


model = SVC(C=1, kernel='sigmoid',gamma='auto',degree=30,coef0=1)
model.fit(X, y)
print('Train accuracy: {:.1%}'.format(model.score(X, y)))
plot_data(X, y)
plot_svm(model,X,)
# Out:
# Train accuracy: 55.6%
# <ipython-input-13-f05539604188>:51: UserWarning: No contour levels were found within the data range.
#   plt.contour(xx1,xx2,z,cmap=plt.cm.gray,vmin=np.inf,vmax=np.inf,levels=[0])

# %% [markdown]
# ## Avaliação de desempenho via validação cruzada $k$-fold
#
# Suponha (como neste exemplo) que você não separou um conjunto de validação. Como saber se seu modelo está sofrendo de overfitting? Como obter uma estimativa de desempenho mais realista do que a acurácia de treinamento?
#
# Uma possível abordagem é usando validação cruzada $k$-fold: particionar os dados em $k$ partes, e realizar $k$ treinamentos e testes, sempre testando em uma das partes um modelo treinado com as partes restantes. A estimativa de desempenho é a média de todos os testes.
#
# Para isso você pode utilizar a função `sklearn.model_selection.cross_val_score()`.
#
# 6. Retorne ao kernel RBF e utilize os hiperparâmetros que você propôs anteriormente.
# 1. Realize uma validação cruzada 5-fold e mostre os resultados obtidos. Calcule também a acurácia média entre as 5 realizações. (Note que não é necessário treinar o modelo antes de aplicar a validação cruzada, pois o treinamento está implícito no método.)
# 1. Comente sobre os resultados observados.
#
# **Obs:** Naturalmente, para uma estimativa de desempenho ainda mais realista, seria necessário avaliar o modelo em um conjunto independente de teste. (OPCIONAL) Por quê?

# %%
# -- Questão 2.6----------OK
from sklearn.model_selection import cross_val_score

model = SVC(C=5, kernel='rbf',gamma=25)
# -- Questão 2.7----------OK
cv=5
fivefold=cross_val_score(model,X,y,cv=cv)
print("Q2.7) O resultado da validação cruzada",cv,"-fold foi:",fivefold)
ffsum=fivefold.sum()*20
print(" e a acurácia média foi de: ","{:.2f}".format(round(ffsum, 2)),"%")
print("Q2.8) Ao observar a acurácia do modelo anterior e a acurácia média obtida com a validação cruzada observa-se",
     "uma diferença de desempenho de aproximadamente [14%], que é considerável. Comparando-se a acurácia de treino com",
     "a acurácia média de validação cruzada pode-se ter uma métrica para o desvio que ocorre quando o modelo treinado",
     " está enviesado pelo conjunto de treinamento e assim corrigir o modelo inicial.")
# Out:
# Q2.7) O resultado da validação cruzada 5 -fold foi: [0.9017341  0.97687861 0.87861272 0.80813953 0.54651163]
#  e a acurácia média foi de:  82.24 %
# Q2.8) Ao observar a acurácia do modelo anterior e a acurácia média obtida com a validação cruzada observa-se uma diferença de desempenho de aproximadamente [14%], que é considerável. Comparando-se a acurácia de treino com a acurácia média de validação cruzada pode-se ter uma métrica para o desvio que ocorre quando o modelo treinado  está enviesado pelo conjunto de treinamento e assim corrigir o modelo inicial.

# %% [markdown]
# # 3. Conjunto de dados #3
#
# O próximo conjunto de dados pode ser carregado pelo comando abaixo. Note que este é o mesmo conjunto utilizado no Exercício 4, exceto que o conjunto de validação agora tem o mesmo tamanho do conjunto de treinamento. (Para fins didáticos, o conjunto de teste continua extremamente grande.)

# %%
from sklearn.datasets import make_moons
np.random.seed(2019*2)
X, y = make_moons(n_samples=200, noise=0.25)
X_val, y_val = make_moons(n_samples=200, noise=0.25)
X_test, y_test = make_moons(n_samples=10000, noise=0.25)
plot_data(X, y)

# %% [markdown]
# ## Busca de hiperparâmetros: Grid search (com implementação própria)
#
# Aqui continuaremos utilizando um classificador SVM com kernel RBF. Sua tarefa é determinar os melhores valores dos hiperparâmetros de acordo com o desempenho no conjunto de validação. Em outras palavras, você deve variar $C$ e $\gamma$, sempre treinando o modelo no conjunto de treinamento e medindo o desempenho no conjunto de validação, até encontrar os valores que maximizam a acurácia de validação.
#
# Para isso, você pode definir os conjuntos `range_C` e `range_gamma` e variar $(C,\gamma)$ dentro da grade `range_C` x `range_gamma` (este método é conhecido como [grid search](https://en.wikipedia.org/wiki/Hyperparameter_optimization#Grid_search)), o que pode ser implementado com dois laços `for`. Para ambos $C$ e $\gamma$, é recomendável utilizar valores que seguem uma progressão geométrica, i.e., regularmente espaçados no expoente.
#
# 1. Implemente seu método completando a função abaixo.
# 1. Em seguida, para os valores encontrados, trace o gráfico da região de decisão (com o conjunto de treinamento) e determine a acurácia nos conjuntos de treinamento, validação e teste.
#
# #### Funções úteis
#
# ```python
# np.logspace()
# ```

# %%
def search_svm(X, y, X_val, y_val):

# --------------------------------------------------------------------------------------
#     '''
#     Finds C and gamma that maximize accuracy on the validation set.

#     Parameters
#     ----------
#     X     : array of shape (m x n) consisting of m training examples.
#     y     : array of shape (m, ) consisting of labels for the training data.
#     X_val : array of shape (m_val x n) consisting of m_val validation examples.
#     y_val : array of shape (m_val, ) consisting of labels for the validation data.
    
#     Returns
#     -------
#     C     : float
#     gamma : float
#     '''
# --------------------------------------------------------------------------------------
    acmax=0
    accuracy=0
    range_C= np.logspace(-2,2,num=50) #cc
    range_gamma= np.logspace(-2,2,num=50)        #gg
    for i in range(0,50):
        for j in range(0,50):

            #training

            model = SVC(C=range_C[i], kernel='rbf',gamma=range_gamma[j])
            model.fit(X,y)

            yhat=model.predict(X_val)

         #   if  model.score(X,y)>acmax:
          #      acmax=model.score(X,y)
            accuracy=model.score(X,y)
           # accuracy=1-np.abs(yhat-y).sum()/y.shape
                
            if  accuracy>acmax:
                acmax=accuracy
                
                cmax=range_C[i]
                gmax=range_gamma[j]
                
    return cmax, gmax

c,g=search_svm(X, y, X_val, y_val)

print("c: ",c,"g: ",g)
y.shape
# Out:
# c:  68.66488450042998 g:  100.0
# (200,)

# %%
#Questão 3.2-------------- Treino
model = SVC(C=c, kernel='rbf',gamma=g)
model.fit(X, y)
yhat=model.predict(X)
print('Acurácia - Treino:\n\n: {:.1%}'.format(model.score(X, y)))
plot_data(X, y)
plot_svm(model,X,circles=False)
# Out:
# Acurácia - Treino:
#
# : 100.0%

# %%
#Questão 3.2-------------- Teste  ERROR 404
model = SVC(C=c, kernel='rbf',gamma=g)
model.fit(X, y)
yhat=model.predict(X_test)
print('Acurácia - Teste:\n\n: {:.1%}'.format(model.score(X_test, y_test))) 
plot_data(X_test, y_test)
plot_svm(model,X_test,circles=False)
# Out:
# Acurácia - Teste:
#
# : 87.1%

# %%
#Questão 3.2-------------- Validação
model = SVC(C=c, kernel='rbf',gamma=g)
model.fit(X, y)
yhat=model.predict(X_val)
print('Acurácia - Validação:\n\n{:.1%}'.format(model.score(X_val, y_val))) 
plot_data(X_val, y_val)
plot_svm(model,X_val,circles=False)
# Out:
# Acurácia - Validação:
#
# 88.5%

# %% [markdown]
# ## Busca de hiperparâmetros: Grid search + Validação cruzada (via sklearn)
#
# Suponha que você não possui ou não deseja separar um conjunto de validação (*hold-out*) como feito acima. Isto é, assuma que `X_val` e `y_val` não existem. Ainda assim é possível obter uma boa estimativa de desempenho---sem usar o conjunto de teste---e utilizá-la para a escolha de hiperparâmetros, utilizando validação cruzada $k$-fold.
#
# Uma forma de implementar esta técnica seria eliminar os argumentos `X_val` e `y_val` da função `search_svm` e alterá-la de forma a utilizar `cross_val_score()`. Para facilitar, vamos diretamente utilizar a biblioteca `sklearn`, a qual já possui uma implementação eficiente da *grid search* com validação cruzada, mais precisamente a função `sklearn.model_selection.GridSearchCV()`.
#
# 3. Realize uma busca de hiperparâmetros através de *grid search* com validação cruzada 5-fold.
# 1. Para o melhor classificador encontrado, trace o gráfico da região de decisão (com o conjunto de treinamento) e determine a acurácia nos conjuntos de treinamento e teste (lembre que não existe mais conjunto de validação separado).
# 1. Comente sobre os resultados observados.
#
# #### Dicas
#
# - Para utilizar a função `GridSearchCV` você precisará definir o argumento `param_grid`. Por exemplo:
#
# ```
# param_grid = {'C':[1,10,100], 'gamma':[0.1,1,10]}
# ```
#
# - Estude a documentação da função `GridSearchCV`. Em particular, as propriedades `.best_estimator_` e `.cv_results_` são interessantes e possivelmente úteis.

# %%
#Questão 3.3-------------- 

from sklearn.model_selection import GridSearchCV
from sklearn import svm
parameters = {'C':[1,100,100], 'gamma':[0.1,1,10]}        #,'kernel':('linear', 'rbf')
svc = svm.SVC()
clf = GridSearchCV(svc, parameters)
clf.fit(X,y)

cstr,gstr=clf.best_params_
bestc=clf.best_params_[cstr]
bestg=clf.best_params_[gstr]
print("O melhores valores encontrados pelo Grid Search + validação cruzada 5-fold foram:",
     "\n\nC: ",bestc,"\n\ng: ",bestg,"\n\n")
#Questão 3.4-------------- 
model = SVC(C=bestc, kernel='rbf',gamma=bestg)
model.fit(X, y)
print('Q)3.4 Acurácia - Treino:\n {:.1%}'.format(model.score(X, y)))
plot_data(X, y)
plot_svm(model,X,circles=False)
# Out:
# O melhores valores encontrados pelo Grid Search + validação cruzada 5-fold foram:
#
# C:  1
#
# g:  1
#
#
# Q)3.4 Acurácia - Treino:
#  92.5%

# %%
#Questão 3.4--------------Continuação

print('Q)3.4 Acurácia - Teste:\n\n {:.1%}'.format(model.score(X_test, y_test)))
plot_data(X_test, y_test)
plot_svm(model,X_test,circles=False)
# Out:
# Q)3.4 Acurácia - Teste:
#
#  93.8%

# %%
#Questão 3.5--------------
print("Q3.5) Percebe-se uma melhor adaptação das regiões de classificação",
      "das amostras quando foi feita a técnica de Grid Search + validação cruzada 5-fold.",
      " Já que no primeiro caso o modelo está visivelmente sofrendo de overfitting, dada a",
      "diferença do alto desempenho de teste (100%) dos procedimentos de teste(87.1%) e validação(88.5%).")
# Out:
# Q3.5) Percebe-se uma melhor adaptação das regiões de classificação das amostras quando foi feita a técnica de Grid Search + validação cruzada 5-fold.  Já que no primeiro caso o modelo está visivelmente sofrendo de overfitting, dada a diferença do alto desempenho de teste (100%) dos procedimentos de teste(87.1%) e validação(88.5%).

# %% [markdown]
# # Conjunto de dados #4
#
# O último conjunto de dados consiste de mensagens sobre tópicos diferentes e a tarefa consiste em identificar o tópico correspondente a cada mensagem. O conjunto completo possui 20 categorias; para uma classificação binária, utilizaremos apenas duas. Mais informações sobre o conjunto de dados podem ser encontradas em:
#
# https://scikit-learn.org/stable/datasets/index.html#the-20-newsgroups-text-dataset
#
# O conjunto de dados pode ser carregado pelos comandos abaixo.

# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['sci.med','soc.religion.christian']
remove = ['headers','footers','quotes']
data_train = fetch_20newsgroups(subset='train',categories=categories, remove=remove)
data_test = fetch_20newsgroups(subset='test',categories=categories, remove=remove)
categories = data_train['target_names'] # just in case it gets reversed
msg = data_train['data']
y = data_train['target']
msg_test = data_test['data']
y_test = data_test['target']

# %%
# A few samples
for i in [9,8]:
    print('\ny = %d (%s)\n-----' % (y[i],categories[y[i]]))
    print(msg[i],'\n')
# Out:
# y = 0 (sci.med)
# -----
# I am currently doing a group research project on the drug Xanax.  I would
# be exponentially gracious to receive any and all information you could
# provide
# me regarding its usage, history, mechanism of reaction, side effects, and
# other pertinent information.  I don't care how long or how short your
# response is.
#
#
# y = 1 (soc.religion.christian)
# -----
#
# I have no doubt that God hears everybody's prayers.
# However, He does things His way, i.e. things will happen
# only if it is His will.
#
# Now if the question really is "Does God grant everybody's wishes ?"
# then you'll get a brutal shot of reality similar to when you didn't
# get that toy you wanted for Christmas. You just cannot expect
# to get everything you want in this world.
#
# --

# %% [markdown]
# ## Pré-processamento dos dados
#
# Para converter texto em vetores numéricos, utilizaremos o modelo _bag-of-words_ (BoW). Leia a seção 4.6-4.6.1 do livro do Watt para se familiar com este conceito.

# %%
from sklearn.feature_extraction.text import CountVectorizer
prep = make_pipeline(CountVectorizer())
X = prep.fit_transform(msg)
X_test = prep.transform(msg_test)
voc = prep.steps[0][1].vocabulary_
inv_voc = {i: v for v, i in voc.items()}

print(voc['research'])
print(inv_voc[15704])
print(X[9].sorted_indices())
# Out:
# 15704
# research
#   (0, 1670)	1
#   (0, 1750)	1
#   (0, 1837)	2
#   (0, 1970)	1
#   (0, 2680)	1
#   (0, 3566)	1
#   (0, 4933)	1
#   (0, 5199)	1
#   (0, 6202)	1
#   (0, 6221)	1
#   (0, 6344)	1
#   (0, 6552)	1
#   (0, 7284)	1
#   (0, 8443)	1
#   (0, 8559)	1
#   (0, 9056)	1
#   (0, 9204)	2
#   (0, 9773)	2
#   (0, 10175)	1
#   (0, 10230)	1
#   (0, 11238)	1
#   (0, 11708)	1
#   (0, 11743)	1
#   (0, 13074)	1
#   (0, 13147)	1
#   (0, 13233)	1
#   (0, 13330)	1
#   (0, 13891)	1
#   (0, 14706)	1
#   (0, 14820)	1
#   (0, 15204)	1
#   (0, 15273)	1
#   (0, 15434)	1
#   (0, 15704)	1
#   (0, 15775)	1
#   (0, 16830)	1
#   (0, 16876)	1
#   (0, 18423)	1
#   (0, 18658)	1
#   (0, 19478)	1
#   (0, 20317)	1
#   (0, 20376)	1
#   (0, 20456)	1
#   (0, 20463)	1

# %% [markdown]
# ## Classificação com SVM linear
#
# Para este exercício você usará apenas um SVM linear. Nesse caso, **não utilize a função `SVC` do sklearn**. Ao invés disso, utilize a função `LinearSVC`, a qual possui uma implementação otimizada para SVM linear.
#
# 1. Treine um SVM linear e encontre os melhores hiperparâmetros (no caso, apenas $C$).
# 1. Para o modelo treinado, calcule a acurácia no conjunto de treinamento via validação cruzada 5-fold, e calcule também a acurácia de teste (hold-out).

# %% [markdown]
# # ~~ Resposta - Exercício 5.4.1 --

# %%
from sklearn.svm import LinearSVC
import warnings

warnings.filterwarnings("ignore")

vet_C = np.logspace(0,1,100,endpoint = True)
acuracia_train_maior = 0
acuracia_test = 0

c_best = 0

for i in range (len(vet_C)):
    model_4_1 = LinearSVC(C=vet_C[i])
    model_4_1.fit(X,y)
    
    scores_4_1 = cross_val_score(model_4_1,X,y,cv=5) #mudou de 'model_4'
    acuracia_train_4_1 =scores_4_1.mean()
    
    if acuracia_train_4_1 > acuracia_train_maior:
        acuracia_train_maior = acuracia_train_4_1
        c_best = vet_C[i]
       # model_4 = model_4_1
     #   acuracia_train = model_4_1.score(X,y)*100

# ------ Para o melhor C encontrado --- C== c_best
model_4_1 = LinearSVC(C=c_best)
model_4_1.fit(X,y)

acuracia_test = model_4_1.score(X_test,y_test)*100      

print('C = {:.6}'.format(c_best))
# Out:
# C = 1.0

# %% [markdown]
# # ~~ Resposta - Exercício 5.4.2 --

# %%
acuracia_train_4_2 =acuracia_train_maior
acuracia_test_4_2 = acuracia_test

print('\nAcurácia do conjunto de treinamento via validação 5-fold:\n{:.4}'.format(acuracia_train_4_2*100),
      "%")

print('\nAcurácia - conjunto de teste utilizando hold-out:\n{:.4}'.format(acuracia_test_4_2),'%')
# Out:
# Acurácia do conjunto de treinamento via validação 5-fold:
# 87.77 %
#
# Acurácia - conjunto de teste utilizando hold-out:
# 85.52 %

# %% [markdown]
# ## Aprimorando o modelo
#
# Você conseguiu pelo menos 94% de acurácia na validação cruzada?
#
# 3. Em caso negativo, tente aprimorar o modelo. Considere, por exemplo, o escalonamento dos atributos. Faz sentido, por exemplo, usar um `StandardScaler`, considerando que $X$ é uma matriz esparsa? Ou faria mais sentido normalizar os atributos internamente a cada amostra? Isto pode ser feito por qualquer das funções abaixo:
# ```python
# sklearn.preprocessing.Normalizer
# sklearn.feature_extraction.text.TfidfTransformer(use_idf=False)
# ```
# 1. Explique o seu raciocínio e os resultados observados.
# 1. Estude a documentação dos transformadores `CountVectorizer` e `TfidfTransformer` e veja se consegue atingir o desempenho desejado.

# %% [markdown]
# # ~~ Resposta - Exercício 5.4.3 --

# %%
from sklearn.svm import LinearSVC
import warnings

from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import Normalizer
from sklearn.feature_extraction.text import TfidfTransformer
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 5.4.3b) Resultados usando StandardScaler ------------------------------------------------

# %%
# --- Preservando o conjunto de dados inicial ------------

X_old=X
X_test_old=X_test

# -------------------------------------------------------------------


# ---------------------------- B) Resultados usando StandardScaler ----------------------------------------------

model_Standard = StandardScaler(with_mean = False).fit(X)
X = model_Standard.transform(X)
X_test= model_Standard.transform(X_test)

vet_C = np.logspace(0,1,100,endpoint = True)
acuracia_train_maior_4_3b  = 0
acuracia_test_4_3b = 0

c_best = 0

for i in range (len(vet_C)):
    model_4_3b = LinearSVC(C=vet_C[i])
    model_4_3b.fit(X,y)
    
    scores_4_3b = cross_val_score(model_4_3b,X,y,cv=5) #mudou de 'model_4'
    acuracia_train_4_3b =scores_4_3b.mean()
    
    if acuracia_train_4_3b > acuracia_train_maior_4_3b :
        acuracia_train_maior_4_3b = acuracia_train_4_3b
        c_best_4_3b  = vet_C[i]

# ------ Para o melhor C encontrado --- C== c_best
model_4_3b = LinearSVC(C=c_best_4_3b )
model_4_3b.fit(X,y)

acuracia_test_4_3b = model_4_3b.score(X_test,y_test)*100     


# --- Retomando conjunto de dados inicial-------------------------||
del X,X_test

X = X_old
X_test = X_test_old 
# ------------------------------------------------------------------

# %% [markdown]
# ### 5.4.3c) Resultados usando Normalizer ------------------------------------------------

# %%
#  ---------------------------- C) Resultados usando Normalizer ------------------------------------------------


norm_transformer = Normalizer().fit(X)
X= norm_transformer.transform(X)
X_test= norm_transformer.transform(X_test)

vet_C = np.logspace(0,1,100,endpoint = True)
acuracia_train_maior_4_3c  = 0
acuracia_test_4_3c = 0

c_best = 0

for i in range (len(vet_C)):
    model_4_3c = LinearSVC(C=vet_C[i])
    model_4_3c.fit(X,y)
    
    scores_4_3c = cross_val_score(model_4_3c,X,y,cv=5) #mudou de 'model_4'
    acuracia_train_4_3c =scores_4_3c.mean()
    
    if acuracia_train_4_3c > acuracia_train_maior_4_3c :
        acuracia_train_maior_4_3c = acuracia_train_4_3c
        c_best_4_3c  = vet_C[i]
       # model_4 = model_4_1
     #   acuracia_train = model_4_1.score(X,y)*100

# ------ Para o melhor C encontrado --- C== c_best
model_4_3c = LinearSVC(C=c_best_4_3c )
model_4_3c.fit(X,y)

acuracia_test_4_3c = model_4_3c.score(X_test,y_test)*100      


# --- Retomando conjunto de dados inicial-------------------------||
del X,X_test

X = X_old
X_test = X_test_old 
# ------------------------------------------------------------------

# %% [markdown]
# ### Comparação de modelos:

# %%
# A) Resultados do modelo simples --------------------------------------

print("--------------------- Modelo Simples ---------------------")
#print('C = {:.6}'.format(c_best))
print('\nAcurácia do conjunto de TREINO ',
      'via validação 5-fold:\n{:.4}'.format(acuracia_train_4_2*100),
      "%")

print('\nAcurácia - conjunto de TESTE utilizando hold-out:\n{:.4}'.format(acuracia_test_4_2),'%')
#print("--------------------------------------------------------------------------------------")

#---------------------------------------------------------------------


# B) Resultados usando StandardScaler ----------------------------------------------

print("\n\n--------------------- Modelo com StandardScaler ---------------------")
#print('C = {:.6}'.format(c_best))
print('\nAcurácia do conjunto de TREINO via ',
      'validação 5-fold:\n{:.4}'.format(acuracia_train_maior_4_3b *100),
      "%")
print('\nAcurácia - conjunto de TESTE utilizando hold-out:\n{:.4}'.format( acuracia_test_4_3b),'%')
#print("--------------------------------------------------------------------------------------")



# C) Resultados usando Normalizer ------------------------------------------------



print("\n\n--------------------- Modelo com Normalizer ---------------------")
#print('C = {:.6}'.format(c_best))
print('\nAcurácia do conjunto de TREINO via ',
      'validação 5-fold:\n{:.4}'.format(acuracia_train_maior_4_3c *100),
      "%")
print('\nAcurácia - conjunto de TESTE utilizando hold-out:\n{:.4}'.format( acuracia_test_4_3c),'%')
#print("--------------------------------------------------------------------------------------")
# Out:
# --------------------- Modelo Simples ---------------------
#
# Acurácia do conjunto de TREINO  via validação 5-fold:
# 87.77 %
#
# Acurácia - conjunto de TESTE utilizando hold-out:
# 85.52 %
#
#
# --------------------- Modelo com StandardScaler ---------------------
#
# Acurácia do conjunto de TREINO via  validação 5-fold:
# 80.56 %
#
# Acurácia - conjunto de TESTE utilizando hold-out:
# 80.35 %
#
#
# --------------------- Modelo com Normalizer ---------------------
#
# Acurácia do conjunto de TREINO via  validação 5-fold:
# 92.88 %
#
# Acurácia - conjunto de TESTE utilizando hold-out:
# 89.67 %

# %% [markdown]
# #### Resposta 5.4.3:
#
# Não faz sentido usar o `StandardScaler` tendo uma matriz `X` esparsa. Isso resultaria numa dificuldade de centralizar os dados antes de usar o `Scaler`, gerando uma matriz densa, que ocuparia,portando, muita memória e levaria o código ao erro.
#
# Pode-se usar, ao invés disso o parâmetro `with_mean=False`

# %% [markdown]
# # ~~ Resposta - Exercício 5.4.4 --

# %% [markdown]
# #### Resposta:
# Sendo X uma matriz esparsa( em formato de texto) faz sentido usar a função `normalizer` pois ela consegue fazer o escalonamento de matrizes deste tipo. Assim, foi possível de se obter uma boa média de validação cruzada (**91.79%**).

# %% [markdown]
# # ~~ Resposta - Exercício 5.4.5 --

# %%
tfidf_transformer = TfidfTransformer()
X = tfidf_transformer.fit_transform(X)
X_test= tfidf_transformer.transform(X_test)


vet_C = np.logspace(0,1,100,endpoint = True)
acuracia_train_maior_4_5 = 0
acuracia_test_4_5 = 0

c_best = 0

for i in range (len(vet_C)):
    model_4_5 = LinearSVC(C=vet_C[i])
    model_4_5.fit(X,y)
    
    scores_4_5 = cross_val_score(model_4_5,X,y,cv=5) #mudou de 'model_4'
    acuracia_train_4_5 =scores_4_5.mean()
    
    if acuracia_train_4_5 > acuracia_train_maior_4_5 :
        acuracia_train_maior_4_5 = acuracia_train_4_5
        c_best_4_5  = vet_C[i]
        
# ------ Para o melhor C encontrado --- C== c_best
model_4_5 = LinearSVC(C=c_best_4_5 )
model_4_5.fit(X,y)

acuracia_test_4_5 = model_4_5.score(X_test,y_test)*100      

print("--------------------- Modelo com TfidfTransformer ---------------------")
#print('C = {:.6}'.format(c_best))
print('\nAcurácia do conjunto de TREINO via ',
      'validação 5-fold:\n{:.4}'.format(acuracia_train_maior_4_5 *100),
      "%")
print('\nAcurácia - conjunto de TESTE utilizando hold-out:\n{:.4}'.format( acuracia_test_4_5),'%')
#print("--------------------------------------------------------------------------------------")


# --- Retomando conjunto de dados inicial-------------------------||
del X,X_test

X = X_old
X_test = X_test_old 
# ------------------------------------------------------------------
# Out:
# --------------------- Modelo com TfidfTransformer ---------------------
#
# Acurácia do conjunto de TREINO via  validação 5-fold:
# 94.64 %
#
# Acurácia - conjunto de TESTE utilizando hold-out:
# 92.19 %

# %% [markdown]
# ## Realizando predições
#
# 6. Determine a predição fornecida pelo seu modelo para os seguintes exemplos (retirados da Wikipedia):
#
# ```
# A vaccine is a biological preparation that provides active acquired immunity to a particular disease.
# ```
#
# ```
# Baptism is the ritual act, with the use of water, by which a person is admitted to membership of the Church.
# ```

# %% [markdown]
# # ~~ Resposta - Exercício 5.4.6 --

# %%
msg1=['A vaccine is a biological preparation that provides active acquired immunity to a particular disease.']
msg2=['Baptism is the ritual act, with the use of water, by which a person is admitted to membership of the Church.']

X_test = prep.transform (msg1)
y_predict_msg1 = model_4_5.predict(X_test)
print('y predict msg1- Classe:\n',y_predict_msg1)

X_test = prep.transform (msg2)
y_predict_msg2 = model_4_5.predict(X_test)
print('y predict msg2 - Classe:\n',y_predict_msg2)
# Out:
# y predict msg1- Classe:
#  [0]
# y predict msg2 - Classe:
#  [1]

# %% [markdown]
# ## Preditores mais importantes
#
# Como o modelo é um classificador linear, podemos determinar quais atributos são mais relevantes para a classificação analisando o vetor de pesos $\bw$.
#
# 7. Determine os 5 vocábulos mais preditivos de cada classe (i.e., 10 no total).
# 1. Quantos atributos são considerados (pelo modelo) absolutamente irrelevantes para a classificação?

# %% [markdown]
# # ~~ Resposta - Exercício 5.4.7 --

# %%
w = model_4_5.coef_

K = 5 
ind = np.argpartition(w[0,:],-K)[-K:]

print('5 vocábulos mais relevantes da classe %s'%categories[1],':\n')
for i in range(K):
    print(inv_voc[ind[i]])
    
print('\n5 vocábulos mais relevantes da classe %s'%categories[0],':\n')
ind_menor = np.argpartition(w[0,:],K)[K:]

for i in range(K):
    print(inv_voc[ind_menor[i]])
# Out:
# 5 vocábulos mais relevantes da classe soc.religion.christian :
#
# christians
# jesus
# church
# god
# christian
#
# 5 vocábulos mais relevantes da classe sci.med :
#
# treatment
# methodology
# research
# physician
# symptoms

# %% [markdown]
# # ~~ Resposta - Exercício 5.4.8 --

# %%
count = 0
ind_irr = np.zeros(w.shape[1])
for i in range (w.shape[1]):
    if w[0,i] == 0:
        ind_irr[count] == i
        count = count + 1

print("Número de atrubutos mais irrelevantes para o modelo: ",(count-1))
# Out:
# Número de atrubutos mais irrelevantes para o modelo:  3268

# %% [markdown]
# # (OPCIONAL)
#
# - Aplique um classificador SVM em outros conjuntos de dados, como por exemplo:
#  - https://scikit-learn.org/stable/datasets/index.html#breast-cancer-dataset
#  - https://scikit-learn.org/stable/datasets/index.html#olivetti-faces-dataset
#  - https://archive.ics.uci.edu/ml/datasets/spambase
